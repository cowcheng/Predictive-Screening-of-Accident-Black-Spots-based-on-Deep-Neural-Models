# %%
# Author        : Cow Cheng
# Date          : 30/06/2024
# Description   : Creating edgelist for length property of edge from the raw edges information

# %%
import os
from pathlib import Path

ROOT_DIR = Path(os.getcwd()).parent.parent.absolute().__str__()

# %%
import pandas as pd

edges_df = pd.read_csv(filepath_or_buffer=f"{ROOT_DIR}/data/raw/osm_edges_info.csv")
edges_df
# Out:
#                 u            v  key      osmid  oneway  lanes  \
# 0        33004487  10813125727    0  102506130    True    3.0
# 1        33004487   9125470653    0  102506142    True    2.0
# 2        33004488   6357916699    0  102640426    True    3.0
# 3        33004488   1151084822    0  250489279    True    2.0
# 4        34971941    332248875    0  493744605    True    2.0
# ...           ...          ...  ...        ...     ...    ...
# 7053  11880893092  11880893093    0  987256892   False    1.0
# 7054  11880893092   9125470644    0  987256892   False    1.0
# 7055  11880893093  11880893092    0  987256892   False    1.0
# 7056  11880893105   6521288995    0  150801664   False    NaN
# 7057  11880893105   4571243168    0  150801664   False    NaN
#
#                                name      highway  reversed  length  \
# 0                   彌敦道 Nathan Road      primary     False  48.365
# 1          眾坊街 Public Square Street    secondary     False   1.845
# ...

# %%
edges_df = edges_df.loc[:, ["u", "v", "length"]]
edges_df
# Out:
#                 u            v  length
# 0        33004487  10813125727  48.365
# 1        33004487   9125470653   1.845
# 2        33004488   6357916699  11.143
# 3        33004488   1151084822  10.668
# 4        34971941    332248875  43.118
# ...           ...          ...     ...
# 7053  11880893092  11880893093   7.312
# 7054  11880893092   9125470644   7.362
# 7055  11880893093  11880893092   7.312
# 7056  11880893105   6521288995   2.668
# 7057  11880893105   4571243168   2.248
#
# [7058 rows x 3 columns]

# %%
edges_list = edges_df.values.tolist()
for edge in edges_list:
    edge[0] = int(edge[0])
    edge[1] = int(edge[1])
    edge[2] = edge[2]
edges_list
# Out:
# [[33004487, 10813125727, 48.365],
#  [33004487, 9125470653, 1.845],
#  [33004488, 6357916699, 11.143],
#  [33004488, 1151084822, 10.668],
#  [34971941, 332248875, 43.118],
#  [245088212, 5135751883, 6.684],
#  [245088214, 8795975506, 6.073],
#  [274242693, 332243940, 9.945],
#  [274242694, 4501965596, 14.687],
#  [274242695, 3230279839, 21.355],
#  [274242705, 274242708, 417.954],
#  [274243013, 274243014, 182.805],
#  [274243014, 4773727051, 42.91],
#  [274243015, 8446511187, 83.523],
#  [274243016, 1181846034, 47.385],
#  [274243016, 8406879034, 9.445],
#  [274243017, 332242393, 32.587],
#  [274243018, 10566992992, 27.382],
#  [274243083, 332233448, 21.63],
#  [274243086, 5103661134, 19.105],
#  [274243086, 5103661131, 18.853],
#  [275908396, 10566992979, 10.663],
#  [275909256, 6374553590, 101.106],
#  [275909450, 7305838958, 26.995],
#  [275909450, 7305838955, 16.145],
#  [275935771, 7600185392, 9.874],
#  [275944916, 4773693609, 7.402],
#  [275945320, 9766361634, 7.366],
# ...

# %%
with open(f"{ROOT_DIR}/data/training/node2vec/length.el", "w") as f:
    for edge in edges_list:
        f.write(f"{edge[0]} {edge[1]} {edge[2]}\n")
